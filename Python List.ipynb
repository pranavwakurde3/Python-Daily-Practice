# %%
list1 = [5,"hello",34.22,True]  #Hetrogenuos
print(list1)
print(len(list1)) #length
# Out:
# [5, 'hello', 34.22, True]
# 4

# %%
list2=[4,2,1,7,8,4,7]
list1.append(9)
print(list1)
# Out:
# [5, 'hello', 34.22, True, 9]

# %%
list1=[32,6,33,18,12]
list1.insert(3,100)
print(list1)
# Out:
# [32, 6, 33, 100, 18, 12]

# %%
list1=[32,6,33,18,12]
list1.remove(6)
list1.pop()
print(list1)
# Out:
# [32, 33, 18]

# %%
list1=[32,6,33,18,12]
print(min(list1)) #O(n)
print(max(list1))
# Out:
# 6
# 33

# %%
list1=[32,6,33,33,18,12]
list1.count(33)
# Out:
# 2

# %%
list1=[32,6,33,18,12]
list1.sort() #O(logn)
print(list1)
list1.reverse() #O(n)
print(list1)
# Out:
# [6, 12, 18, 32, 33]
# [33, 32, 18, 12, 6]

# %%
list=[1,5,3,4,6,2,5,3]
print(list.index(2))
print(list.index(5,2))
# Out:
# 5
# 6

# %%
list1=[1,2,3]
list2=list1  #Deep copy

list2.append(4)

print(list1)
print(list2)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
list1=[1,2,3]
list2=list1.copy()   #Shallow Copy

list2.append(4)

print(list1)
print(list2)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
list1=[3,4,756,789,45,26,89,18,665,789]
print(list1[2:6])
print(list1[2:8:3])
print(list1[:5])
print(list1[6:])
print(list1[:])
print(list1[::-1])  #reverse
# Out:
# [756, 789, 45, 26]
# [756, 26]
# [3, 4, 756, 789, 45]
# [89, 18, 665, 789]
# [3, 4, 756, 789, 45, 26, 89, 18, 665, 789]
# [789, 665, 18, 89, 26, 45, 789, 756, 4, 3]
